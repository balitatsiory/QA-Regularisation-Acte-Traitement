# %%
print("helllo")
# Out:
# helllo

# %%
with open("../test-data/FAHATERAHANA.TXT", "r",encoding="utf-8") as file:
   content = file.read()

# %%
import re


ligne = """1981;192;FAHATERAHANA;20081981;0900;...ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif;;;...ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif;;;"""

fichiers = re.findall(r'\b[\w\-]+\.tif\b', ligne)

print(fichiers)
# Out:
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif', 'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif']
