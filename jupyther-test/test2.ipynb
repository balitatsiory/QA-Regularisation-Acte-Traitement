# %%
import re

# %%
fichiersBDD = []
with open("../test-data/acte_traitement.csv", "r",encoding="utf-8") as file:
   for line in file:
      ligne=line.strip()
      fichiersBDD.extend(re.findall(r'\b[\w\-]+\.tif\b', ligne))
fichiersBDD=list(set(fichiersBDD))
fichiersBDD
# Out:
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000141-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000172-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000142-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000152-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000139-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000134-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000159-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000189-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000186-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000153-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000173-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000176-01.tif',
#  'ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000174-01.tif',
# ...

# %%
fichiersMentions = []
i=0
with open("../test-data/SORATRA_ANTSISINY.TXT", "r",encoding="utf-8") as file:
   for line in file:
      ligne=line.strip()
      m = re.findall(r'\b[\w\-]+\.tif\b', ligne)
      if m == [] or m == None:
         i+=1
         continue
      fichiersMentions.append([m[0], i])
      i+=1
fichiersMentions
# Out:
# [['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000133-01.tif', 1],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000141-01.tif', 2],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000142-01.tif', 3],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000143-01.tif', 4],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000172-01.tif', 5],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000181-01.tif', 6],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000182-01.tif', 7],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000184-01.tif', 8],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000188-01.tif', 9],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000189-01.tif', 10],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000189-01.tif', 11],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif', 12],
# ...

# %%
print(len(fichiersBDD))
print("\n".join(fichiersBDD))
# Out:
# 14
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000137-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000141-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000173-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000186-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000176-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000134-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000142-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000189-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000172-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000159-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000174-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000152-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000153-01.tif
# ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000139-01.tif

# %%
fichiersFAHATERAHANA = []
manquants = []
i=0
with open("../test-data/FAHATERAHANA.TXT", "r",encoding="utf-8") as file:
   for line in file:
      ligne=line.strip()
      fichier_image=re.findall(r'\b[\w\-]+\.tif\b', ligne)
      fichier_image=list(set(fichier_image))
      print(fichier_image)
      if fichier_image == None or fichier_image == []:
         i+=1
         continue
      if fichier_image not in fichiersFAHATERAHANA:
         fichiersFAHATERAHANA.extend(fichier_image)
         if fichier_image[0] not in fichiersBDD:
            manquants.append([fichier_image[0] , i])
      i+=1
len(fichiersFAHATERAHANA)
# Out:
# []
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000130-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000132-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000129-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000133-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000134-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000135-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000136-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000137-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000138-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000139-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000140-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000141-01.tif']
# ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000142-01.tif']
# ...

# %%
print(len(manquants))
print("\n".join(manquants))
# Out:
# 50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 print(len(manquants))
# ----> 2 print("\n".join(manquants))
#
# TypeError: sequence item 0: expected str instance, list found

# %%
insertMentions = []
insertActeTraitement = []
for m in manquants:
   for item in fichiersMentions:
      if m[0] == item[0]:
         insertMentions.append(item)
   insertActeTraitement.append(m)
print(len(insertMentions))
insertMentions
# Out:
# 8
# [['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000133-01.tif', 1],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000143-01.tif', 4],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000181-01.tif', 6],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000182-01.tif', 7],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000184-01.tif', 8],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000188-01.tif', 9],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif', 12],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif', 13]]

# %%
print(len(insertActeTraitement))
insertActeTraitement
# Out:
# 50
# [['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000130-01.tif', 1],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000132-01.tif', 2],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000129-01.tif', 3],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000133-01.tif', 4],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000135-01.tif', 6],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000136-01.tif', 7],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000138-01.tif', 9],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000140-01.tif', 11],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000143-01.tif', 14],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000144-01.tif', 15],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000145-01.tif', 16],
#  ['ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000146-01.tif', 17],
# ...

# %%
def extract_numero_acte_by_nomtif(nomtif: str) -> str:
    # On cherche la séquence d'alphanumériques avant le dernier tiret suivi de chiffres
    match = re.search(r'_([0-9A-Za-z]+)-\d+\.tif$', nomtif)
    if match:
        value = match.group(1)
        return value
        # if value.isdigit():
        #     return str(int(value))  # supprime les zéros initiaux
        # else:
        #     return re.sub(r'^0+', '', value)  # supprime les zéros initiaux si alphanumérique
    return None
 
# row = "1981;192;FAHATERAHANA;20081981;0900;20081981;0900;;;;;;;;10081981;2200;ANTANETIBE, FIRAISAMPOKONTANY ANTANIRABA;RAMINIRINA;Lovasoa, Claudine;V;;;;;;;;;;;;;;;;;;;;;;;;D;;;;;;;;;;;;;Justine;18101952;;;;;;;;;;;;;;;;;;;º;;;[0.303, 0.214, 0.377, 0.24, 1];;[0.231, 0.101, 0.284, 0.131, 1];;[0.08, 0.125, 0.38, 0.161, 1];;[0.107, 0.219, 0.155, 0.241, 1];;[0.664, 0.386, 0.731, 0.414, 1];;[0.107, 0.219, 0.155, 0.241, 1];;[0.664, 0.386, 0.731, 0.414, 1];;;;;;;;;;;;;;;;[0.703, 0.101, 0.765, 0.134, 1];;[0.447, 0.156, 0.508, 0.182, 1];;[0.805, 0.149, 0.945, 0.178, 1];;[0.094, 0.157, 0.336, 0.19, 1];;;;[0.669, 0.207, 0.798, 0.245, 1];;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;[0.671, 0.259, 0.74, 0.29, 1];;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;1981;192;FAHATERAHANA;20081981;0900;10081981;2200;ANTANETIBE, FIRAISAMPOKONTANY ANTANIRABA;RAMINIRINA;Lovasoa, Claudine;V;;D;;;;;;;Justine;18101952;;;;;;;;;;;;;;ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif;;;[0.303, 0.214, 0.377, 0.24, 1];;[0.231, 0.101, 0.284, 0.131, 1];;[0.08, 0.125, 0.38, 0.161, 1];;[0.107, 0.219, 0.155, 0.241, 1];;[0.664, 0.386, 0.731, 0.414, 1];;[0.703, 0.101, 0.765, 0.134, 1];;[0.447, 0.156, 0.508, 0.182, 1];;[0.805, 0.149, 0.945, 0.178, 1];;[0.094, 0.157, 0.336, 0.19, 1];;;;[0.669, 0.207, 0.798, 0.245, 1];;;;;;;;;;;;;;;;;;;;;;;;[0.671, 0.259, 0.74, 0.29, 1];;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;"
row = ";;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000190-01.tif;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000190-01.tif;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;"
# nom_tif ="ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000192-01.tif"
nom_tif ="ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000190-01.tif"
rowsplit=row.split(";")
imagesplit=nom_tif.split("_")
print(imagesplit)
print([(
            # idacte, # idacte
            # idActeTraitement1, # idacte_source
            # str(idetape_v2), # idetape_v2
            "1", # idemploye_traite
            None, # idemploye_encours
            2, # id_status
            # str(idaffaire), # idaffaire
            row, # datasource
            None, # debut_traitement
            # datetime.now(), # fin_traitement
            1, # numero_duplication
            rowsplit[1], # num_acte
            rowsplit[0], # annee_acte
            True, # auto_insert
            1, # version_actuel
            "NA", # type_acte
            "Recital", # nom_editeur
            "V2", # version_editeur
            # path_dossier_affaire, # pathdossier
            str(rowsplit[0]) + ";"*74 + str(';'.join(rowsplit[74:])) , # datasource_source
            # nom_tif, # nom_tif
            False, # exported
            1, # version_acte
            1, # status_acte
            "MONTEST", # commentaire
            # nom_tif, # image_filename
            imagesplit[0], # region
            imagesplit[1], # district
            imagesplit[2], # commune
            str(rowsplit[0]), # annee
            imagesplit[4], # tome
            imagesplit[5], # registre
            extract_numero_acte_by_nomtif(nom_tif) if len(str(rowsplit[1])) == 0 else str(rowsplit[1]), # numero_acte
            "AUTRES" if len(str(rowsplit[2])) == 0  else str(rowsplit[2]), # sous_type_acte
            None  # livraison 
      )])
# Out:
# ['ANALAMANGA', 'Ambohidratrimo', 'Antehiroka', '1981', 'TOME-01', 'N003', '000190-01.tif']
# ...

# %%
extract_numero_acte_by_nomtif("ANALAMANGA_Ambohidratrimo_Antehiroka_1981_TOME-01_N003_000190-01.tif")
# Out:
# '000190'
